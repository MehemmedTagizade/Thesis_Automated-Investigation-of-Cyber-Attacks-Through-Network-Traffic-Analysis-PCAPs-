# %% [markdown]
# <a href="https://colab.research.google.com/github/MehemmedTagizade/Thesis_Automated-Investigation-of-Cyber-Attacks-Through-Network-Traffic-Analysis-PCAPs-/blob/TEST-CODES/taks3_improved_Isolation_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
file_path = '/content/drive/MyDrive/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv'


data = pd.read_csv(file_path)

# %%
print(data.columns)  # See the actual column names
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
data.rename(columns=lambda x: x.strip(), inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %%
import pandas as pd

# Load your dataset (replace 'your_dataset.csv' with the actual filename)


# Check if "Label" column exists
if "Label" in data.columns:
    unique_labels = data["Label"].unique()
    print(f"Unique values in 'Label' column: {unique_labels}")
    print(f"Number of unique values: {len(unique_labels)}")
else:
    print("No 'Label' column found in this dataset.")
# Count occurrences of each label
label_counts = data["Label"].value_counts()

# Convert to percentages
label_percentages = (label_counts / label_counts.sum()) * 100

# Display the results
print(label_percentages)
# Out:
# Unique values in 'Label' column: ['BENIGN' 'DDoS']
# Number of unique values: 2
# Label
# DDoS      56.713105
# BENIGN    43.286895
# Name: count, dtype: float64

# %%
# Clean column names by removing extra spaces
data.columns = data.columns.str.replace(' ', '')
print(data.columns)
# Out:
# Index(['DestinationPort', 'FlowDuration', 'TotalFwdPackets',
#        'TotalBackwardPackets', 'TotalLengthofFwdPackets',
#        'TotalLengthofBwdPackets', 'FwdPacketLengthMax', 'FwdPacketLengthMin',
#        'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax',
#        'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd',
#        'FlowBytes/s', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd',
#        'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd',
#        'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd',
#        'BwdIATMax', 'BwdIATMin', 'FwdPSHFlags', 'BwdPSHFlags', 'FwdURGFlags',
#        'BwdURGFlags', 'FwdHeaderLength', 'BwdHeaderLength', 'FwdPackets/s',
#        'BwdPackets/s', 'MinPacketLength', 'MaxPacketLength',
#        'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance',
#        'FINFlagCount', 'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount',
#        'ACKFlagCount', 'URGFlagCount', 'CWEFlagCount', 'ECEFlagCount',
#        'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize',
#        'AvgBwdSegmentSize', 'FwdHeaderLength.1', 'FwdAvgBytes/Bulk',
#        'FwdAvgPackets/Bulk', 'FwdAvgBulkRate', 'BwdAvgBytes/Bulk',
#        'BwdAvgPackets/Bulk', 'BwdAvgBulkRate', 'SubflowFwdPackets',
#        'SubflowFwdBytes', 'SubflowBwdPackets', 'SubflowBwdBytes',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'ActiveMean', 'ActiveStd', 'ActiveMax',
#        'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin', 'Label'],
#       dtype='object')

# %%
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.dropna(inplace=True)

# Display the first 10 rows of the dataset
print("First 10 rows of the dataset:")
print(data.head(10))
# Out:
# First 10 rows of the dataset:
#    DestinationPort  FlowDuration  TotalFwdPackets  TotalBackwardPackets  \
# 0            54865             3                2                     0
# 1            55054           109                1                     1
# 2            55055            52                1                     1
# 3            46236            34                1                     1
# 4            54863             3                2                     0
# 5            54871          1022                2                     0
# 6            54925             4                2                     0
# 7            54925            42                1                     1
# 8             9282             4                2                     0
# 9            55153             4                2                     0
#
#    TotalLengthofFwdPackets  TotalLengthofBwdPackets  FwdPacketLengthMax  \
# 0                       12                        0                   6
# 1                        6                        6                   6
# 2                        6                        6                   6
# 3                        6                        6                   6
# 4                       12                        0                   6
# 5                       12                        0                   6
# 6                       12                        0                   6
# 7                        6                        6                   6
# 8                       12                        0                   6
# 9                       37                        0                  31
#
#    FwdPacketLengthMin  FwdPacketLengthMean  FwdPacketLengthStd  ...  \
# 0                   6                  6.0             0.00000  ...
# 1                   6                  6.0             0.00000  ...
# 2                   6                  6.0             0.00000  ...
# 3                   6                  6.0             0.00000  ...
# 4                   6                  6.0             0.00000  ...
# 5                   6                  6.0             0.00000  ...
# 6                   6                  6.0             0.00000  ...
# 7                   6                  6.0             0.00000  ...
# 8                   6                  6.0             0.00000  ...
# 9                   6                 18.5            17.67767  ...
#
#    min_seg_size_forward  ActiveMean  ActiveStd  ActiveMax  ActiveMin  \
# 0                    20         0.0        0.0          0          0
# 1                    20         0.0        0.0          0          0
# 2                    20         0.0        0.0          0          0
# 3                    20         0.0        0.0          0          0
# 4                    20         0.0        0.0          0          0
# 5                    20         0.0        0.0          0          0
# 6                    20         0.0        0.0          0          0
# 7                    20         0.0        0.0          0          0
# 8                    20         0.0        0.0          0          0
# 9                    20         0.0        0.0          0          0
#
#    IdleMean  IdleStd  IdleMax  IdleMin   Label
# 0       0.0      0.0        0        0  BENIGN
# 1       0.0      0.0        0        0  BENIGN
# 2       0.0      0.0        0        0  BENIGN
# 3       0.0      0.0        0        0  BENIGN
# 4       0.0      0.0        0        0  BENIGN
# 5       0.0      0.0        0        0  BENIGN
# 6       0.0      0.0        0        0  BENIGN
# 7       0.0      0.0        0        0  BENIGN
# 8       0.0      0.0        0        0  BENIGN
# 9       0.0      0.0        0        0  BENIGN
#
# [10 rows x 79 columns]

# %%
print(data.isnull().sum())
# Out:
# DestinationPort            0
# FlowDuration               0
# TotalFwdPackets            0
# TotalBackwardPackets       0
# TotalLengthofFwdPackets    0
#                           ..
# IdleMean                   0
# IdleStd                    0
# IdleMax                    0
# IdleMin                    0
# Label                      0
# Length: 79, dtype: int64

# %%
print(data['Label'].value_counts())
# Out:
# Label
# DDoS      128025
# BENIGN     97686
# Name: count, dtype: int64

# %%
irrelevant_columns = [
    'FwdPSHFlags', 'BwdPSHFlags', 'FwdURGFlags', 'BwdURGFlags',
    'CWEFlagCount', 'ECEFlagCount', 'FwdHeaderLength.1',
    'FwdAvgBytes/Bulk', 'FwdAvgPackets/Bulk', 'FwdAvgBulkRate',
    'BwdAvgBytes/Bulk', 'BwdAvgPackets/Bulk', 'BwdAvgBulkRate',
    'Init_Win_bytes_forward', 'Init_Win_bytes_backward',
    'SubflowFwdPackets', 'SubflowFwdBytes', 'SubflowBwdPackets', 'SubflowBwdBytes',
    'ActiveMean', 'ActiveStd', 'ActiveMax', 'ActiveMin',
    'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin'
]

data = data.drop(columns=irrelevant_columns, errors='ignore')
print(data.columns)
print(len(data.columns))
# Out:
# Index(['DestinationPort', 'FlowDuration', 'TotalFwdPackets',
#        'TotalBackwardPackets', 'TotalLengthofFwdPackets',
#        'TotalLengthofBwdPackets', 'FwdPacketLengthMax', 'FwdPacketLengthMin',
#        'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax',
#        'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd',
#        'FlowBytes/s', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd',
#        'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd',
#        'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd',
#        'BwdIATMax', 'BwdIATMin', 'FwdHeaderLength', 'BwdHeaderLength',
#        'FwdPackets/s', 'BwdPackets/s', 'MinPacketLength', 'MaxPacketLength',
#        'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance',
#        'FINFlagCount', 'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount',
#        'ACKFlagCount', 'URGFlagCount', 'Down/UpRatio', 'AveragePacketSize',
#        'AvgFwdSegmentSize', 'AvgBwdSegmentSize', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'Label'],
#       dtype='object')
# 52

# %%
begnin_count = data[data['Label'] == 'BENIGN'].shape[0]
print(f"Number of BENIGN samples: {begnin_count}")

ddos_count = data[data['Label'] == 'DDoS'].shape[0]
print(f"Number of DDoS samples: {ddos_count}")
# Out:
# Number of BENIGN samples: 97686
# Number of DDoS samples: 128025

# %%
from math import floor
benign_samples = data[data['Label'] == 'BENIGN']
percentage = 0.1
malicious_samples = data[data['Label'] == 'DDoS'].sample(n=floor((begnin_count*percentage)/(1-percentage)), random_state=42)

# Combine the sampled data
data = pd.concat([benign_samples, malicious_samples])

# Shuffle the data
data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
print(data['Label'].value_counts())
# Out:
# Label
# BENIGN    97686
# DDoS      10854
# Name: count, dtype: int64

# %%
# Calculate the correlation matrix, ignoring non-numerical columns
correlation_matrix = data.select_dtypes(include=[np.number]).corr()

# Find highly correlated features (e.g., with correlation > 0.9)
high_corr = correlation_matrix[correlation_matrix > 0.9]
print(high_corr)
# Out:
#                          DestinationPort  FlowDuration  TotalFwdPackets  \
# DestinationPort                      1.0           NaN              NaN
# FlowDuration                         NaN       1.00000              NaN
# TotalFwdPackets                      NaN           NaN         1.000000
# TotalBackwardPackets                 NaN           NaN         0.964653
# TotalLengthofFwdPackets              NaN           NaN              NaN
# TotalLengthofBwdPackets              NaN           NaN         0.949403
# FwdPacketLengthMax                   NaN           NaN              NaN
# FwdPacketLengthMin                   NaN           NaN              NaN
# FwdPacketLengthMean                  NaN           NaN              NaN
# FwdPacketLengthStd                   NaN           NaN              NaN
# BwdPacketLengthMax                   NaN           NaN              NaN
# BwdPacketLengthMin                   NaN           NaN              NaN
# BwdPacketLengthMean                  NaN           NaN              NaN
# BwdPacketLengthStd                   NaN           NaN              NaN
# FlowBytes/s                          NaN           NaN              NaN
# FlowPackets/s                        NaN           NaN              NaN
# FlowIATMean                          NaN           NaN              NaN
# FlowIATStd                           NaN           NaN              NaN
# FlowIATMax                           NaN           NaN              NaN
# FlowIATMin                           NaN           NaN              NaN
# FwdIATTotal                          NaN       0.99449              NaN
# FwdIATMean                           NaN           NaN              NaN
# FwdIATStd                            NaN           NaN              NaN
# FwdIATMax                            NaN           NaN              NaN
# FwdIATMin                            NaN           NaN              NaN
# BwdIATTotal                          NaN       0.93165              NaN
# BwdIATMean                           NaN           NaN              NaN
# BwdIATStd                            NaN           NaN              NaN
# BwdIATMax                            NaN           NaN              NaN
# BwdIATMin                            NaN           NaN              NaN
# FwdHeaderLength                      NaN           NaN         0.968461
# BwdHeaderLength                      NaN           NaN         0.936233
# FwdPackets/s                         NaN           NaN              NaN
# BwdPackets/s                         NaN           NaN              NaN
# MinPacketLength                      NaN           NaN              NaN
# MaxPacketLength                      NaN           NaN              NaN
# PacketLengthMean                     NaN           NaN              NaN
# PacketLengthStd                      NaN           NaN              NaN
# PacketLengthVariance                 NaN           NaN              NaN
# FINFlagCount                         NaN           NaN              NaN
# SYNFlagCount                         NaN           NaN              NaN
# RSTFlagCount                         NaN           NaN              NaN
# PSHFlagCount                         NaN           NaN              NaN
# ACKFlagCount                         NaN           NaN              NaN
# URGFlagCount                         NaN           NaN              NaN
# Down/UpRatio                         NaN           NaN              NaN
# AveragePacketSize                    NaN           NaN              NaN
# AvgFwdSegmentSize                    NaN           NaN              NaN
# AvgBwdSegmentSize                    NaN           NaN              NaN
# act_data_pkt_fwd                     NaN           NaN              NaN
# min_seg_size_forward                 NaN           NaN              NaN
#
#                          TotalBackwardPackets  TotalLengthofFwdPackets  \
# DestinationPort                           NaN                      NaN
# FlowDuration                              NaN                      NaN
# TotalFwdPackets                      0.964653                      NaN
# TotalBackwardPackets                 1.000000                      NaN
# TotalLengthofFwdPackets                   NaN                      1.0
# TotalLengthofBwdPackets              0.975649                      NaN
# FwdPacketLengthMax                        NaN                      NaN
# FwdPacketLengthMin                        NaN                      NaN
# FwdPacketLengthMean                       NaN                      NaN
# FwdPacketLengthStd                        NaN                      NaN
# BwdPacketLengthMax                        NaN                      NaN
# BwdPacketLengthMin                        NaN                      NaN
# BwdPacketLengthMean                       NaN                      NaN
# BwdPacketLengthStd                        NaN                      NaN
# FlowBytes/s                               NaN                      NaN
# FlowPackets/s                             NaN                      NaN
# FlowIATMean                               NaN                      NaN
# FlowIATStd                                NaN                      NaN
# FlowIATMax                                NaN                      NaN
# FlowIATMin                                NaN                      NaN
# FwdIATTotal                               NaN                      NaN
# FwdIATMean                                NaN                      NaN
# FwdIATStd                                 NaN                      NaN
# FwdIATMax                                 NaN                      NaN
# FwdIATMin                                 NaN                      NaN
# BwdIATTotal                               NaN                      NaN
# BwdIATMean                                NaN                      NaN
# BwdIATStd                                 NaN                      NaN
# BwdIATMax                                 NaN                      NaN
# BwdIATMin                                 NaN                      NaN
# FwdHeaderLength                      0.944840                      NaN
# BwdHeaderLength                      0.975351                      NaN
# FwdPackets/s                              NaN                      NaN
# BwdPackets/s                              NaN                      NaN
# MinPacketLength                           NaN                      NaN
# MaxPacketLength                           NaN                      NaN
# PacketLengthMean                          NaN                      NaN
# PacketLengthStd                           NaN                      NaN
# PacketLengthVariance                      NaN                      NaN
# FINFlagCount                              NaN                      NaN
# SYNFlagCount                              NaN                      NaN
# RSTFlagCount                              NaN                      NaN
# PSHFlagCount                              NaN                      NaN
# ACKFlagCount                              NaN                      NaN
# URGFlagCount                              NaN                      NaN
# Down/UpRatio                              NaN                      NaN
# AveragePacketSize                         NaN                      NaN
# AvgFwdSegmentSize                         NaN                      NaN
# AvgBwdSegmentSize                         NaN                      NaN
# act_data_pkt_fwd                          NaN                      NaN
# min_seg_size_forward                      NaN                      NaN
#
#                          TotalLengthofBwdPackets  FwdPacketLengthMax  \
# DestinationPort                              NaN                 NaN
# FlowDuration                                 NaN                 NaN
# TotalFwdPackets                         0.949403                 NaN
# TotalBackwardPackets                    0.975649                 NaN
# TotalLengthofFwdPackets                      NaN                 NaN
# TotalLengthofBwdPackets                 1.000000                 NaN
# FwdPacketLengthMax                           NaN            1.000000
# FwdPacketLengthMin                           NaN                 NaN
# FwdPacketLengthMean                          NaN            0.935375
# FwdPacketLengthStd                           NaN            0.991173
# BwdPacketLengthMax                           NaN                 NaN
# BwdPacketLengthMin                           NaN                 NaN
# BwdPacketLengthMean                          NaN                 NaN
# BwdPacketLengthStd                           NaN                 NaN
# FlowBytes/s                                  NaN                 NaN
# FlowPackets/s                                NaN                 NaN
# FlowIATMean                                  NaN                 NaN
# FlowIATStd                                   NaN                 NaN
# FlowIATMax                                   NaN                 NaN
# FlowIATMin                                   NaN                 NaN
# FwdIATTotal                                  NaN                 NaN
# FwdIATMean                                   NaN                 NaN
# FwdIATStd                                    NaN                 NaN
# FwdIATMax                                    NaN                 NaN
# FwdIATMin                                    NaN                 NaN
# BwdIATTotal                                  NaN                 NaN
# BwdIATMean                                   NaN                 NaN
# BwdIATStd                                    NaN                 NaN
# BwdIATMax                                    NaN                 NaN
# BwdIATMin                                    NaN                 NaN
# FwdHeaderLength                         0.932363                 NaN
# BwdHeaderLength                         0.950975                 NaN
# FwdPackets/s                                 NaN                 NaN
# BwdPackets/s                                 NaN                 NaN
# MinPacketLength                              NaN                 NaN
# MaxPacketLength                              NaN                 NaN
# PacketLengthMean                             NaN                 NaN
# PacketLengthStd                              NaN                 NaN
# PacketLengthVariance                         NaN                 NaN
# FINFlagCount                                 NaN                 NaN
# SYNFlagCount                                 NaN                 NaN
# RSTFlagCount                                 NaN                 NaN
# PSHFlagCount                                 NaN                 NaN
# ACKFlagCount                                 NaN                 NaN
# URGFlagCount                                 NaN                 NaN
# Down/UpRatio                                 NaN                 NaN
# AveragePacketSize                            NaN                 NaN
# AvgFwdSegmentSize                            NaN            0.935375
# AvgBwdSegmentSize                            NaN                 NaN
# act_data_pkt_fwd                             NaN                 NaN
# min_seg_size_forward                         NaN                 NaN
#
#                          FwdPacketLengthMin  FwdPacketLengthMean  \
# DestinationPort                         NaN                  NaN
# FlowDuration                            NaN                  NaN
# TotalFwdPackets                         NaN                  NaN
# TotalBackwardPackets                    NaN                  NaN
# TotalLengthofFwdPackets                 NaN                  NaN
# TotalLengthofBwdPackets                 NaN                  NaN
# FwdPacketLengthMax                      NaN             0.935375
# FwdPacketLengthMin                      1.0                  NaN
# FwdPacketLengthMean                     NaN             1.000000
# FwdPacketLengthStd                      NaN             0.913301
# BwdPacketLengthMax                      NaN                  NaN
# BwdPacketLengthMin                      NaN                  NaN
# BwdPacketLengthMean                     NaN                  NaN
# BwdPacketLengthStd                      NaN                  NaN
# FlowBytes/s                             NaN                  NaN
# FlowPackets/s                           NaN                  NaN
# FlowIATMean                             NaN                  NaN
# FlowIATStd                              NaN                  NaN
# FlowIATMax                              NaN                  NaN
# FlowIATMin                              NaN                  NaN
# FwdIATTotal                             NaN                  NaN
# FwdIATMean                              NaN                  NaN
# FwdIATStd                               NaN                  NaN
# FwdIATMax                               NaN                  NaN
# FwdIATMin                               NaN                  NaN
# BwdIATTotal                             NaN                  NaN
# BwdIATMean                              NaN                  NaN
# BwdIATStd                               NaN                  NaN
# BwdIATMax                               NaN                  NaN
# BwdIATMin                               NaN                  NaN
# FwdHeaderLength                         NaN                  NaN
# BwdHeaderLength                         NaN                  NaN
# FwdPackets/s                            NaN                  NaN
# BwdPackets/s                            NaN                  NaN
# MinPacketLength                         NaN                  NaN
# MaxPacketLength                         NaN                  NaN
# PacketLengthMean                        NaN                  NaN
# PacketLengthStd                         NaN                  NaN
# PacketLengthVariance                    NaN                  NaN
# FINFlagCount                            NaN                  NaN
# SYNFlagCount                            NaN                  NaN
# RSTFlagCount                            NaN                  NaN
# PSHFlagCount                            NaN                  NaN
# ACKFlagCount                            NaN                  NaN
# URGFlagCount                            NaN                  NaN
# Down/UpRatio                            NaN                  NaN
# AveragePacketSize                       NaN                  NaN
# AvgFwdSegmentSize                       NaN             1.000000
# AvgBwdSegmentSize                       NaN                  NaN
# act_data_pkt_fwd                        NaN                  NaN
# min_seg_size_forward                    NaN                  NaN
#
#                          FwdPacketLengthStd  ...  RSTFlagCount  PSHFlagCount  \
# DestinationPort                         NaN  ...           NaN           NaN
# FlowDuration                            NaN  ...           NaN           NaN
# TotalFwdPackets                         NaN  ...           NaN           NaN
# TotalBackwardPackets                    NaN  ...           NaN           NaN
# TotalLengthofFwdPackets                 NaN  ...           NaN           NaN
# TotalLengthofBwdPackets                 NaN  ...           NaN           NaN
# FwdPacketLengthMax                 0.991173  ...           NaN           NaN
# FwdPacketLengthMin                      NaN  ...           NaN           NaN
# FwdPacketLengthMean                0.913301  ...           NaN           NaN
# FwdPacketLengthStd                 1.000000  ...           NaN           NaN
# BwdPacketLengthMax                      NaN  ...           NaN           NaN
# BwdPacketLengthMin                      NaN  ...           NaN           NaN
# BwdPacketLengthMean                     NaN  ...           NaN           NaN
# BwdPacketLengthStd                      NaN  ...           NaN           NaN
# FlowBytes/s                             NaN  ...           NaN           NaN
# FlowPackets/s                           NaN  ...           NaN           NaN
# FlowIATMean                             NaN  ...           NaN           NaN
# FlowIATStd                              NaN  ...           NaN           NaN
# FlowIATMax                              NaN  ...           NaN           NaN
# FlowIATMin                              NaN  ...           NaN           NaN
# FwdIATTotal                             NaN  ...           NaN           NaN
# FwdIATMean                              NaN  ...           NaN           NaN
# FwdIATStd                               NaN  ...           NaN           NaN
# FwdIATMax                               NaN  ...           NaN           NaN
# FwdIATMin                               NaN  ...           NaN           NaN
# BwdIATTotal                             NaN  ...           NaN           NaN
# BwdIATMean                              NaN  ...           NaN           NaN
# BwdIATStd                               NaN  ...           NaN           NaN
# BwdIATMax                               NaN  ...           NaN           NaN
# BwdIATMin                               NaN  ...           NaN           NaN
# FwdHeaderLength                         NaN  ...           NaN           NaN
# BwdHeaderLength                         NaN  ...           NaN           NaN
# FwdPackets/s                            NaN  ...           NaN           NaN
# BwdPackets/s                            NaN  ...           NaN           NaN
# MinPacketLength                         NaN  ...           NaN           NaN
# MaxPacketLength                         NaN  ...           NaN           NaN
# PacketLengthMean                        NaN  ...           NaN           NaN
# PacketLengthStd                         NaN  ...           NaN           NaN
# PacketLengthVariance                    NaN  ...           NaN           NaN
# FINFlagCount                            NaN  ...           NaN           NaN
# SYNFlagCount                            NaN  ...           NaN           NaN
# RSTFlagCount                            NaN  ...           1.0           NaN
# PSHFlagCount                            NaN  ...           NaN           1.0
# ACKFlagCount                            NaN  ...           NaN           NaN
# URGFlagCount                            NaN  ...           NaN           NaN
# Down/UpRatio                            NaN  ...           NaN           NaN
# AveragePacketSize                       NaN  ...           NaN           NaN
# AvgFwdSegmentSize                  0.913301  ...           NaN           NaN
# AvgBwdSegmentSize                       NaN  ...           NaN           NaN
# act_data_pkt_fwd                        NaN  ...           NaN           NaN
# min_seg_size_forward                    NaN  ...           NaN           NaN
#
#                          ACKFlagCount  URGFlagCount  Down/UpRatio  \
# DestinationPort                   NaN           NaN           NaN
# FlowDuration                      NaN           NaN           NaN
# TotalFwdPackets                   NaN           NaN           NaN
# TotalBackwardPackets              NaN           NaN           NaN
# TotalLengthofFwdPackets           NaN           NaN           NaN
# TotalLengthofBwdPackets           NaN           NaN           NaN
# FwdPacketLengthMax                NaN           NaN           NaN
# FwdPacketLengthMin                NaN           NaN           NaN
# FwdPacketLengthMean               NaN           NaN           NaN
# FwdPacketLengthStd                NaN           NaN           NaN
# BwdPacketLengthMax                NaN           NaN           NaN
# BwdPacketLengthMin                NaN           NaN           NaN
# BwdPacketLengthMean               NaN           NaN           NaN
# BwdPacketLengthStd                NaN           NaN           NaN
# FlowBytes/s                       NaN           NaN           NaN
# FlowPackets/s                     NaN           NaN           NaN
# FlowIATMean                       NaN           NaN           NaN
# FlowIATStd                        NaN           NaN           NaN
# FlowIATMax                        NaN           NaN           NaN
# FlowIATMin                        NaN           NaN           NaN
# FwdIATTotal                       NaN           NaN           NaN
# FwdIATMean                        NaN           NaN           NaN
# FwdIATStd                         NaN           NaN           NaN
# FwdIATMax                         NaN           NaN           NaN
# FwdIATMin                         NaN           NaN           NaN
# BwdIATTotal                       NaN           NaN           NaN
# BwdIATMean                        NaN           NaN           NaN
# BwdIATStd                         NaN           NaN           NaN
# BwdIATMax                         NaN           NaN           NaN
# BwdIATMin                         NaN           NaN           NaN
# FwdHeaderLength                   NaN           NaN           NaN
# BwdHeaderLength                   NaN           NaN           NaN
# FwdPackets/s                      NaN           NaN           NaN
# BwdPackets/s                      NaN           NaN           NaN
# MinPacketLength                   NaN           NaN           NaN
# MaxPacketLength                   NaN           NaN           NaN
# PacketLengthMean                  NaN           NaN           NaN
# PacketLengthStd                   NaN           NaN           NaN
# PacketLengthVariance              NaN           NaN           NaN
# FINFlagCount                      NaN           NaN           NaN
# SYNFlagCount                      NaN           NaN           NaN
# RSTFlagCount                      NaN           NaN           NaN
# PSHFlagCount                      NaN           NaN           NaN
# ACKFlagCount                      1.0           NaN           NaN
# URGFlagCount                      NaN           1.0           NaN
# Down/UpRatio                      NaN           NaN           1.0
# AveragePacketSize                 NaN           NaN           NaN
# AvgFwdSegmentSize                 NaN           NaN           NaN
# AvgBwdSegmentSize                 NaN           NaN           NaN
# act_data_pkt_fwd                  NaN           NaN           NaN
# min_seg_size_forward              NaN           NaN           NaN
#
#                          AveragePacketSize  AvgFwdSegmentSize  \
# DestinationPort                        NaN                NaN
# FlowDuration                           NaN                NaN
# TotalFwdPackets                        NaN                NaN
# TotalBackwardPackets                   NaN                NaN
# TotalLengthofFwdPackets                NaN                NaN
# TotalLengthofBwdPackets                NaN                NaN
# FwdPacketLengthMax                     NaN           0.935375
# FwdPacketLengthMin                     NaN                NaN
# FwdPacketLengthMean                    NaN           1.000000
# FwdPacketLengthStd                     NaN           0.913301
# BwdPacketLengthMax                     NaN                NaN
# BwdPacketLengthMin                     NaN                NaN
# BwdPacketLengthMean                    NaN                NaN
# BwdPacketLengthStd                     NaN                NaN
# FlowBytes/s                            NaN                NaN
# FlowPackets/s                          NaN                NaN
# FlowIATMean                            NaN                NaN
# FlowIATStd                             NaN                NaN
# FlowIATMax                             NaN                NaN
# FlowIATMin                             NaN                NaN
# FwdIATTotal                            NaN                NaN
# FwdIATMean                             NaN                NaN
# FwdIATStd                              NaN                NaN
# FwdIATMax                              NaN                NaN
# FwdIATMin                              NaN                NaN
# BwdIATTotal                            NaN                NaN
# BwdIATMean                             NaN                NaN
# BwdIATStd                              NaN                NaN
# BwdIATMax                              NaN                NaN
# BwdIATMin                              NaN                NaN
# FwdHeaderLength                        NaN                NaN
# BwdHeaderLength                        NaN                NaN
# FwdPackets/s                           NaN                NaN
# BwdPackets/s                           NaN                NaN
# MinPacketLength                        NaN                NaN
# MaxPacketLength                        NaN                NaN
# PacketLengthMean                  0.998665                NaN
# PacketLengthStd                   0.947461                NaN
# PacketLengthVariance                   NaN                NaN
# FINFlagCount                           NaN                NaN
# SYNFlagCount                           NaN                NaN
# RSTFlagCount                           NaN                NaN
# PSHFlagCount                           NaN                NaN
# ACKFlagCount                           NaN                NaN
# URGFlagCount                           NaN                NaN
# Down/UpRatio                           NaN                NaN
# AveragePacketSize                 1.000000                NaN
# AvgFwdSegmentSize                      NaN           1.000000
# AvgBwdSegmentSize                      NaN                NaN
# act_data_pkt_fwd                       NaN                NaN
# min_seg_size_forward                   NaN                NaN
#
#                          AvgBwdSegmentSize  act_data_pkt_fwd  \
# DestinationPort                        NaN               NaN
# FlowDuration                           NaN               NaN
# TotalFwdPackets                        NaN               NaN
# TotalBackwardPackets                   NaN               NaN
# TotalLengthofFwdPackets                NaN               NaN
# TotalLengthofBwdPackets                NaN               NaN
# FwdPacketLengthMax                     NaN               NaN
# FwdPacketLengthMin                     NaN               NaN
# FwdPacketLengthMean                    NaN               NaN
# FwdPacketLengthStd                     NaN               NaN
# BwdPacketLengthMax                0.962241               NaN
# BwdPacketLengthMin                     NaN               NaN
# BwdPacketLengthMean               1.000000               NaN
# BwdPacketLengthStd                0.944281               NaN
# FlowBytes/s                            NaN               NaN
# FlowPackets/s                          NaN               NaN
# FlowIATMean                            NaN               NaN
# FlowIATStd                             NaN               NaN
# FlowIATMax                             NaN               NaN
# FlowIATMin                             NaN               NaN
# FwdIATTotal                            NaN               NaN
# FwdIATMean                             NaN               NaN
# FwdIATStd                              NaN               NaN
# FwdIATMax                              NaN               NaN
# FwdIATMin                              NaN               NaN
# BwdIATTotal                            NaN               NaN
# BwdIATMean                             NaN               NaN
# BwdIATStd                              NaN               NaN
# BwdIATMax                              NaN               NaN
# BwdIATMin                              NaN               NaN
# FwdHeaderLength                        NaN               NaN
# BwdHeaderLength                        NaN               NaN
# FwdPackets/s                           NaN               NaN
# BwdPackets/s                           NaN               NaN
# MinPacketLength                        NaN               NaN
# MaxPacketLength                        NaN               NaN
# PacketLengthMean                       NaN               NaN
# PacketLengthStd                        NaN               NaN
# PacketLengthVariance                   NaN               NaN
# FINFlagCount                           NaN               NaN
# SYNFlagCount                           NaN               NaN
# RSTFlagCount                           NaN               NaN
# PSHFlagCount                           NaN               NaN
# ACKFlagCount                           NaN               NaN
# URGFlagCount                           NaN               NaN
# Down/UpRatio                           NaN               NaN
# AveragePacketSize                      NaN               NaN
# AvgFwdSegmentSize                      NaN               NaN
# AvgBwdSegmentSize                 1.000000               NaN
# act_data_pkt_fwd                       NaN               1.0
# min_seg_size_forward                   NaN               NaN
#
#                          min_seg_size_forward
# DestinationPort                           NaN
# FlowDuration                              NaN
# TotalFwdPackets                           NaN
# TotalBackwardPackets                      NaN
# TotalLengthofFwdPackets                   NaN
# TotalLengthofBwdPackets                   NaN
# FwdPacketLengthMax                        NaN
# FwdPacketLengthMin                        NaN
# FwdPacketLengthMean                       NaN
# FwdPacketLengthStd                        NaN
# BwdPacketLengthMax                        NaN
# BwdPacketLengthMin                        NaN
# BwdPacketLengthMean                       NaN
# BwdPacketLengthStd                        NaN
# FlowBytes/s                               NaN
# FlowPackets/s                             NaN
# FlowIATMean                               NaN
# FlowIATStd                                NaN
# FlowIATMax                                NaN
# FlowIATMin                                NaN
# FwdIATTotal                               NaN
# FwdIATMean                                NaN
# FwdIATStd                                 NaN
# FwdIATMax                                 NaN
# FwdIATMin                                 NaN
# BwdIATTotal                               NaN
# BwdIATMean                                NaN
# BwdIATStd                                 NaN
# BwdIATMax                                 NaN
# BwdIATMin                                 NaN
# FwdHeaderLength                           NaN
# BwdHeaderLength                           NaN
# FwdPackets/s                              NaN
# BwdPackets/s                              NaN
# MinPacketLength                           NaN
# MaxPacketLength                           NaN
# PacketLengthMean                          NaN
# PacketLengthStd                           NaN
# PacketLengthVariance                      NaN
# FINFlagCount                              NaN
# SYNFlagCount                              NaN
# RSTFlagCount                              NaN
# PSHFlagCount                              NaN
# ACKFlagCount                              NaN
# URGFlagCount                              NaN
# Down/UpRatio                              NaN
# AveragePacketSize                         NaN
# AvgFwdSegmentSize                         NaN
# AvgBwdSegmentSize                         NaN
# act_data_pkt_fwd                          NaN
# min_seg_size_forward                      1.0
#
# [51 rows x 51 columns]

# %% [markdown]
# DONE++++

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from itertools import product

# === Step 1: Prepare features and labels ===
labels = data['Label'].values
features = data.drop(columns=['Label'])

# Encode labels (BENIGN = 0, DDoS = 1)
y_encoded = np.where(labels == 'BENIGN', 0, 1)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# === Step 2: Separate BENIGN and DDoS samples ===
X_benign = features_scaled[y_encoded == 0]
X_ddos = features_scaled[y_encoded == 1]

# === Step 3: Split BENIGN into train/cv/test ===
n_benign = len(X_benign)
np.random.seed(42)
idx = np.random.permutation(n_benign)

train_end = int(0.7 * n_benign)
cv_end = int(0.85 * n_benign)

X_train = X_benign[idx[:train_end]]
X_cv_benign = X_benign[idx[train_end:cv_end]]
X_test_benign = X_benign[idx[cv_end:]]

# === Step 4: Split DDoS into cv/test ===
n_ddos = len(X_ddos)
np.random.seed(42)
idx_ddos = np.random.permutation(n_ddos)
half = n_ddos // 2

X_cv_ddos = X_ddos[idx_ddos[:half]]
X_test_ddos = X_ddos[idx_ddos[half:]]

# === Step 5: Create CV and Test Sets ===
X_cv = np.vstack((X_cv_benign, X_cv_ddos))
y_cv = np.concatenate((np.zeros(len(X_cv_benign)), np.ones(len(X_cv_ddos))))

X_test = np.vstack((X_test_benign, X_test_ddos))
y_test = np.concatenate((np.zeros(len(X_test_benign)), np.ones(len(X_test_ddos))))

# === Step 6: Define hyperparameter grid ===
contamination_list = [0.01, 0.03, 0.05]
n_estimators_list = [100, 200]
max_samples_list = [0.5, 1.0]

param_grid = list(product(contamination_list, n_estimators_list, max_samples_list))
results = []

# === Step 7: Grid Search on CV Set ===
for contamination, n_estimators, max_samples in param_grid:
    model = IsolationForest(
        contamination=contamination,
        n_estimators=n_estimators,
        max_samples=max_samples,
        random_state=42
    )
    model.fit(X_train)
    preds = model.predict(X_cv)
    preds = np.where(preds == -1, 1, 0)

    report = classification_report(y_cv, preds, output_dict=True)
    f1 = report['weighted avg']['f1-score']
    results.append(((contamination, n_estimators, max_samples), f1))

    print(f"Contamination={contamination}, n_estimators={n_estimators}, max_samples={max_samples} → F1: {f1:.4f}")

# === Step 8: Report best config ===
best = max(results, key=lambda x: x[1])
best_params = best[0]
print(f"\n✅ Best Params → Contamination={best_params[0]}, n_estimators={best_params[1]}, max_samples={best_params[2]} with F1={best[1]:.4f}")

# === Step 9: Retrain with best config and evaluate on TEST set ===
model = IsolationForest(
    contamination=best_params[0],
    n_estimators=best_params[1],
    max_samples=best_params[2],
    random_state=42
)
model.fit(X_train)
test_preds = model.predict(X_test)
test_preds = np.where(test_preds == -1, 1, 0)

# === Accuracy Calculation ===
accuracy = accuracy_score(y_test, test_preds)
print(f"\n✅ Test Accuracy: {accuracy:.4f}")

# === Final Evaluation ===
print("\n=== Final Test Set Results ===")
print(classification_report(y_test, test_preds))
ConfusionMatrixDisplay.from_predictions(y_test, test_preds, display_labels=['BENIGN', 'DDoS'], cmap='Blues')
plt.title("Test Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Contamination=0.01, n_estimators=100, max_samples=0.5 → F1: 0.8702
# Contamination=0.01, n_estimators=100, max_samples=1.0 → F1: 0.8695
# Contamination=0.01, n_estimators=200, max_samples=0.5 → F1: 0.8601
# Contamination=0.01, n_estimators=200, max_samples=1.0 → F1: 0.8678
# Contamination=0.03, n_estimators=100, max_samples=0.5 → F1: 0.8691
# Contamination=0.03, n_estimators=100, max_samples=1.0 → F1: 0.8676
# Contamination=0.03, n_estimators=200, max_samples=0.5 → F1: 0.8678
# Contamination=0.03, n_estimators=200, max_samples=1.0 → F1: 0.8681
# Contamination=0.05, n_estimators=100, max_samples=0.5 → F1: 0.8567
# Contamination=0.05, n_estimators=100, max_samples=1.0 → F1: 0.8567
# Contamination=0.05, n_estimators=200, max_samples=0.5 → F1: 0.8566
# Contamination=0.05, n_estimators=200, max_samples=1.0 → F1: 0.8564
#
# ✅ Best Params → Contamination=0.01, n_estimators=100, max_samples=0.5 with F1=0.8702
#
# ✅ Test Accuracy: 0.8810
#
# === Final Test Set Results ===
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.92     14653
#          1.0       0.96      0.58      0.73      5427
#
#     accuracy                           0.88     20080
#    macro avg       0.91      0.79      0.83     20080
# weighted avg       0.89      0.88      0.87     20080

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from itertools import product

# === Step 1: Prepare features and labels ===
labels = data['Label'].values
features = data.drop(columns=['Label'])

# Encode labels (BENIGN = 0, DDoS = 1)
y_encoded = np.where(labels == 'BENIGN', 0, 1)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# === Step 2: Separate BENIGN and DDoS samples ===
X_benign = features_scaled[y_encoded == 0]
X_ddos = features_scaled[y_encoded == 1]

# === Step 3: Split BENIGN into train/cv/test ===
n_benign = len(X_benign)
np.random.seed(42)
idx = np.random.permutation(n_benign)

train_end = int(0.5 * n_benign)
cv_end = int(0.75 * n_benign)

X_train = X_benign[idx[:train_end]]
X_cv_benign = X_benign[idx[train_end:cv_end]]
X_test_benign = X_benign[idx[cv_end:]]

# === Step 4: Split DDoS into cv/test ===
n_ddos = len(X_ddos)
np.random.seed(42)
idx_ddos = np.random.permutation(n_ddos)
half = n_ddos // 2

X_cv_ddos = X_ddos[idx_ddos[:half]]
X_test_ddos = X_ddos[idx_ddos[half:]]

# === Step 5: Create CV and Test Sets ===
X_cv = np.vstack((X_cv_benign, X_cv_ddos))
y_cv = np.concatenate((np.zeros(len(X_cv_benign)), np.ones(len(X_cv_ddos))))

X_test = np.vstack((X_test_benign, X_test_ddos))
y_test = np.concatenate((np.zeros(len(X_test_benign)), np.ones(len(X_test_ddos))))

# === Step 6: Define hyperparameter grid ===
contamination_list = [0.01, 0.03, 0.05]
n_estimators_list = [100, 200]
max_samples_list = [0.5, 1.0]

param_grid = list(product(contamination_list, n_estimators_list, max_samples_list))
results = []

# === Step 7: Grid Search on CV Set ===
for contamination, n_estimators, max_samples in param_grid:
    model = IsolationForest(
        contamination=contamination,
        n_estimators=n_estimators,
        max_samples=max_samples,
        random_state=42
    )
    model.fit(X_train)
    preds = model.predict(X_cv)
    preds = np.where(preds == -1, 1, 0)

    report = classification_report(y_cv, preds, output_dict=True)
    f1 = report['weighted avg']['f1-score']
    results.append(((contamination, n_estimators, max_samples), f1))

    print(f"Contamination={contamination}, n_estimators={n_estimators}, max_samples={max_samples} → F1: {f1:.4f}")

# === Step 8: Report best config ===
best = max(results, key=lambda x: x[1])
best_params = best[0]
print(f"\n✅ Best Params → Contamination={best_params[0]}, n_estimators={best_params[1]}, max_samples={best_params[2]} with F1={best[1]:.4f}")

# === Step 9: Retrain with best config and evaluate on TEST set ===
model = IsolationForest(
    contamination=best_params[0],
    n_estimators=best_params[1],
    max_samples=best_params[2],
    random_state=42
)
model.fit(X_train)
test_preds = model.predict(X_test)
test_preds = np.where(test_preds == -1, 1, 0)

# === Accuracy Calculation ===
accuracy = accuracy_score(y_test, test_preds)
print(f"\n✅ Test Accuracy: {accuracy:.4f}")

# === Final Evaluation ===
print("\n=== Final Test Set Results ===")
print(classification_report(y_test, test_preds))
ConfusionMatrixDisplay.from_predictions(y_test, test_preds, display_labels=['BENIGN', 'DDoS'], cmap='Blues')
plt.title("Test Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Contamination=0.01, n_estimators=100, max_samples=0.5 → F1: 0.9002
# Contamination=0.01, n_estimators=100, max_samples=1.0 → F1: 0.9153
# Contamination=0.01, n_estimators=200, max_samples=0.5 → F1: 0.8989
# Contamination=0.01, n_estimators=200, max_samples=1.0 → F1: 0.9095
# Contamination=0.03, n_estimators=100, max_samples=0.5 → F1: 0.9031
# Contamination=0.03, n_estimators=100, max_samples=1.0 → F1: 0.9033
# Contamination=0.03, n_estimators=200, max_samples=0.5 → F1: 0.9026
# Contamination=0.03, n_estimators=200, max_samples=1.0 → F1: 0.9030
# Contamination=0.05, n_estimators=100, max_samples=0.5 → F1: 0.8892
# Contamination=0.05, n_estimators=100, max_samples=1.0 → F1: 0.8893
# Contamination=0.05, n_estimators=200, max_samples=0.5 → F1: 0.8889
# Contamination=0.05, n_estimators=200, max_samples=1.0 → F1: 0.8890
#
# ✅ Best Params → Contamination=0.01, n_estimators=100, max_samples=1.0 with F1=0.9153
#
# ✅ Test Accuracy: 0.9222
#
# === Final Test Set Results ===
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95     24422
#          1.0       0.93      0.62      0.74      5427
#
#     accuracy                           0.92     29849
#    macro avg       0.92      0.80      0.85     29849
# weighted avg       0.92      0.92      0.92     29849

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt

# === Step 1: Prepare features and labels ===
labels = data['Label'].values
features = data.drop(columns=['Label'])

# Encode labels (BENIGN = 0, DDoS = 1)
y_encoded = np.where(labels == 'BENIGN', 0, 1)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# === Step 2: Separate BENIGN and DDoS samples ===
X_benign = features_scaled[y_encoded == 0]
X_ddos = features_scaled[y_encoded == 1]

# === Step 3: Split BENIGN into train/cv/test ===
n_benign = len(X_benign)
np.random.seed(42)
idx = np.random.permutation(n_benign)

train_end = int(0.6 * n_benign)
cv_end = int(0.8 * n_benign)

X_train = X_benign[idx[:train_end]]
X_cv_benign = X_benign[idx[train_end:cv_end]]
X_test_benign = X_benign[idx[cv_end:]]

# === Step 4: Split DDoS into cv/test ===
n_ddos = len(X_ddos)
idx_ddos = np.random.permutation(n_ddos)
half = n_ddos // 2

X_cv_ddos = X_ddos[idx_ddos[:half]]
X_test_ddos = X_ddos[idx_ddos[half:]]

# === Step 5: Create CV and Test Sets ===
X_cv = np.vstack((X_cv_benign, X_cv_ddos))
y_cv = np.concatenate((np.zeros(len(X_cv_benign)), np.ones(len(X_cv_ddos))))

X_test = np.vstack((X_test_benign, X_test_ddos))
y_test = np.concatenate((np.zeros(len(X_test_benign)), np.ones(len(X_test_ddos))))

# === Step 6: Train Isolation Forest ===
model = IsolationForest(
    contamination=0.01,  # You can try 0.015 or 0.02 for better recall
    n_estimators=100,
    max_samples=1.0,
    random_state=42
)
model.fit(X_train)

# === Step 7: Use decision_function and custom threshold ===
scores_test = model.decision_function(X_test)

# 🔧 TUNABLE THRESHOLD — increase this percentile to reduce FN
threshold = np.percentile(scores_test, 2.0)  # Try 4.0 or 5.0 for better recall
test_preds = (scores_test < threshold).astype(int)

# === Step 8: Evaluate Performance ===
accuracy = accuracy_score(y_test, test_preds)
print(f"\n✅ Test Accuracy: {accuracy:.4f}")
print("\n=== Final Test Set Results ===")
print(classification_report(y_test, test_preds))

# === Step 9: Show Confusion Matrix ===
ConfusionMatrixDisplay.from_predictions(y_test, test_preds, display_labels=['BENIGN', 'DDoS'], cmap='Blues')
plt.title("Isolation Forest - Tuned Threshold")
plt.tight_layout()
plt.show()
# Out:
# ✅ Test Accuracy: 0.8019
#
# === Final Test Set Results ===
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89     19538
#          1.0       0.98      0.09      0.17      5427
#
#     accuracy                           0.80     24965
#    macro avg       0.89      0.55      0.53     24965
# weighted avg       0.84      0.80      0.73     24965

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, recall_score
import matplotlib.pyplot as plt

# === Step 1: Prepare features and labels ===
labels = data['Label'].values
features = data.drop(columns=['Label'])

# Encode labels (BENIGN = 0, DDoS = 1)
y_encoded = np.where(labels == 'BENIGN', 0, 1)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# === Step 2: Separate BENIGN and DDoS samples ===
X_benign = features_scaled[y_encoded == 0]
X_ddos = features_scaled[y_encoded == 1]

# === Step 3: Split BENIGN into train/cv/test ===
n_benign = len(X_benign)
np.random.seed(42)
idx = np.random.permutation(n_benign)

train_end = int(0.6 * n_benign)
cv_end = int(0.8 * n_benign)

X_train = X_benign[idx[:train_end]]
X_cv_benign = X_benign[idx[train_end:cv_end]]
X_test_benign = X_benign[idx[cv_end:]]

# === Step 4: Split DDoS into cv/test ===
n_ddos = len(X_ddos)
np.random.seed(42)
idx_ddos = np.random.permutation(n_ddos)
half = n_ddos // 2

X_cv_ddos = X_ddos[idx_ddos[:half]]
X_test_ddos = X_ddos[idx_ddos[half:]]

# === Step 5: Create CV and Test Sets ===
X_cv = np.vstack((X_cv_benign, X_cv_ddos))
y_cv = np.concatenate((np.zeros(len(X_cv_benign)), np.ones(len(X_cv_ddos))))

X_test = np.vstack((X_test_benign, X_test_ddos))
y_test = np.concatenate((np.zeros(len(X_test_benign)), np.ones(len(X_test_ddos))))

# === Step 6: Train Isolation Forest ===
model = IsolationForest(contamination=0.1, random_state=42)
model.fit(X_train)

# === Step 7: Use decision_function and loop through thresholds ===
scores_test = -model.decision_function(X_test)  # Flip sign: higher = more anomalous
thresholds = np.percentile(scores_test, np.arange(80, 100, 1))
recalls = []
false_negatives = []

for t in thresholds:
    preds = (scores_test > t).astype(int)
    recall = recall_score(y_test, preds)

    cm = confusion_matrix(y_test, preds)
    fn = cm[1][0]  # False Negatives: actual 1 predicted 0

    recalls.append(recall)
    false_negatives.append(fn)

# === Step 8: Plot recall and FN vs threshold ===
plt.figure(figsize=(10,5))
plt.plot(np.arange(80, 100, 1), recalls, label='Recall (DDoS)', marker='o')
plt.plot(np.arange(80, 100, 1), false_negatives, label='False Negatives', marker='x')
plt.title("Threshold vs Recall & FN")
plt.xlabel("Threshold Percentile")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt

# === Step 1: Prepare features and labels ===
labels = data['Label'].values
features = data.drop(columns=['Label'])

# Encode labels (BENIGN = 0, DDoS = 1)
y_encoded = np.where(labels == 'BENIGN', 0, 1)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# === Step 2: Separate BENIGN and DDoS samples ===
X_benign = features_scaled[y_encoded == 0]
X_ddos = features_scaled[y_encoded == 1]

# === Step 3: Split BENIGN into train/cv/test ===
n_benign = len(X_benign)
np.random.seed(42)
idx = np.random.permutation(n_benign)

train_end = int(0.5 * n_benign)
cv_end = int(0.25 * n_benign)

X_train = X_benign[idx[:train_end]]
X_cv_benign = X_benign[idx[train_end:cv_end]]
X_test_benign = X_benign[idx[cv_end:]]

# === Step 4: Split DDoS into cv/test ===
n_ddos = len(X_ddos)
np.random.seed(42)
idx_ddos = np.random.permutation(n_ddos)
half = n_ddos // 2

X_cv_ddos = X_ddos[idx_ddos[:half]]
X_test_ddos = X_ddos[idx_ddos[half:]]

# === Step 5: Create CV and Test Sets ===
X_cv = np.vstack((X_cv_benign, X_cv_ddos))
y_cv = np.concatenate((np.zeros(len(X_cv_benign)), np.ones(len(X_cv_ddos))))

X_test = np.vstack((X_test_benign, X_test_ddos))
y_test = np.concatenate((np.zeros(len(X_test_benign)), np.ones(len(X_test_ddos))))

# === Step 6: Train Isolation Forest ===
model = IsolationForest(
    contamination=0.1,  # Can try 0.15 to widen anomaly detection
    n_estimators=100,
    max_samples=1.0,
    random_state=42
)
model.fit(X_train)

# === Step 7: Predict with custom threshold to reduce FN ===
scores_test = -model.decision_function(X_test)  # Higher = more anomalous
threshold = np.percentile(scores_test, 80)  # Lower threshold = more alerts → lower FN
test_preds = (scores_test > threshold).astype(int)

# === Step 8: Evaluation ===
accuracy = accuracy_score(y_test, test_preds)
print(f"\n✅ Accuracy: {accuracy:.4f}")
print("\n=== Classification Report ===")
print(classification_report(y_test, test_preds))

# Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_test, test_preds, display_labels=['BENIGN', 'DDoS'], cmap='Blues')
plt.title("Isolation Forest - Low Threshold (80th Percentile)")
plt.tight_layout()
plt.show()
# Out:
# ✅ Accuracy: 0.8188
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.83      0.90     73265
#          1.0       0.22      0.64      0.33      5427
#
#     accuracy                           0.82     78692
#    macro avg       0.59      0.73      0.61     78692
# weighted avg       0.92      0.82      0.86     78692
